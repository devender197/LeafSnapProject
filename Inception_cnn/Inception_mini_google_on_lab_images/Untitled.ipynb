# %%
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
import os
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder
from ImageToArrayPreprocessor import ImageToArrayPreprocessor
from SimpleDatasetLoader import SimpleDatasetLoader
from aspectawarepreprocessor import AspectAwarePreprocessor
from keras.models import load_model
import pandas as pd

# %%
imagePaths = list()
label = list()
labels = list()

# walk through the directory to get all the images paths
for x in os.walk("/home/devpc/PycharmProjects/DeepNN_ComputerVision/LeafSnapProject/leafsnap-dataset/dataset/images/lab"):
    for filename in x[2]:
        filePath = f'{x[0]}/{filename}'
        imagePaths.append(filePath)

    s_index = x[0].rindex('/')
    # labels of classes in folder
    label.append(x[0][s_index + 1:])

# Intialize Preprocessor for image
# AspectAwarePreprocessor crop the image with respect to short dimensions
aap = AspectAwarePreprocessor(64, 64)
# ImageToArrayPreprocessor convert the image to array
iap = ImageToArrayPreprocessor()

# SimpleDatasetLoader convert image to array and process the image as per given processor
sdl = SimpleDatasetLoader(preprocessors=[aap, iap])
(data, labels) = sdl.load(imagePaths, verbose=500)
data = data.astype("float") / 255.0

# convert the labels from integers to vectors
le = LabelEncoder().fit(labels)
labels = np_utils.to_categorical(le.transform(labels), len(le.classes_))
(trainX, testX, trainY, testY) = train_test_split(data,
                                                  labels, test_size=0.20, stratify=labels, random_state=42)
# load model
model = load_model("Inception_model_on_lab_data/Inception_model_100_lab.hdf5")
# load model
predictions = model.predict(testX, batch_size=64)
report = classification_report(testY.argmax(axis=1), predictions.argmax(axis=1),
                               target_names=le.classes_, output_dict=True)
# saving the classification report in csv format
df = pd.DataFrame(report).transpose()
df.to_csv("classification_report_lab.csv")
# Out:
# [INFO] processed 500/23147
# [INFO] processed 1000/23147
# [INFO] processed 1500/23147
# [INFO] processed 2000/23147
# [INFO] processed 2500/23147
# [INFO] processed 3000/23147
# [INFO] processed 3500/23147
# [INFO] processed 4000/23147
# [INFO] processed 4500/23147
# [INFO] processed 5000/23147
# [INFO] processed 5500/23147
# [INFO] processed 6000/23147
# [INFO] processed 6500/23147
# [INFO] processed 7000/23147
# [INFO] processed 7500/23147
# [INFO] processed 8000/23147
# [INFO] processed 8500/23147
# [INFO] processed 9000/23147
# [INFO] processed 9500/23147
# [INFO] processed 10000/23147
# [INFO] processed 10500/23147
# [INFO] processed 11000/23147
# [INFO] processed 11500/23147
# [INFO] processed 12000/23147
# [INFO] processed 12500/23147
# [INFO] processed 13000/23147
# [INFO] processed 13500/23147
# [INFO] processed 14000/23147
# [INFO] processed 14500/23147
# [INFO] processed 15000/23147
# [INFO] processed 15500/23147
# [INFO] processed 16000/23147
# [INFO] processed 16500/23147
# [INFO] processed 17000/23147
# [INFO] processed 17500/23147
# [INFO] processed 18000/23147
# [INFO] processed 18500/23147
# [INFO] processed 19000/23147
# [INFO] processed 19500/23147
# [INFO] processed 20000/23147
# [INFO] processed 20500/23147
# [INFO] processed 21000/23147
# [INFO] processed 21500/23147
# [INFO] processed 22000/23147
# [INFO] processed 22500/23147
# [INFO] processed 23000/23147
# /home/devpc/.virtualenvs/DeepNN_ComputerVision/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
pd.read_csv("classification_report_lab.csv")
# Out:
#              Unnamed: 0  precision    recall  f1-score      support
# 0        abies_concolor   1.000000  0.150000  0.260870    40.000000
# 1    abies_nordmanniana   0.000000  0.000000  0.000000    25.000000
# 2        acer_campestre   1.000000  0.181818  0.307692    22.000000
# 3          acer_ginnala   0.866667  0.541667  0.666667    24.000000
# 4          acer_griseum   0.590909  0.812500  0.684211    16.000000
# ..                  ...        ...       ...       ...          ...
# 183         ulmus_rubra   0.806452  0.462963  0.588235    54.000000
# 184     zelkova_serrata   1.000000  0.208333  0.344828    24.000000
# 185            accuracy   0.589417  0.589417  0.589417     0.589417
# 186           macro avg   0.755817  0.571765  0.578104  4630.000000
# 187        weighted avg   0.760311  0.589417  0.591680  4630.000000
#
# [188 rows x 5 columns]

# %%
imagePaths = list()
label = list()
labels = list()



# walk through the directory to get all the images paths
for x in os.walk("/home/devpc/PycharmProjects/DeepNN_ComputerVision/LeafSnapProject/leafsnap-dataset/dataset/images/field"):
    for filename in x[2]:
        filePath = f'{x[0]}/{filename}'
        imagePaths.append(filePath)

    s_index = x[0].rindex('/')
    # labels of classes in folder
    label.append(x[0][s_index + 1:])

# Intialize Preprocessor for image
# AspectAwarePreprocessor crop the image with respect to short dimensions
aap = AspectAwarePreprocessor(64, 64)
# ImageToArrayPreprocessor convert the image to array
iap = ImageToArrayPreprocessor()

# SimpleDatasetLoader convert image to array and process the image as per given processor
sdl = SimpleDatasetLoader(preprocessors=[aap, iap])
(data, labels) = sdl.load(imagePaths, verbose=500)
data = data.astype("float") / 255.0

# convert the labels from integers to vectors
le = LabelEncoder().fit(labels)
labels = np_utils.to_categorical(le.transform(labels), len(le.classes_))
(trainX, testX, trainY, testY) = train_test_split(data,
                                                  labels, test_size=0.20, stratify=labels, random_state=42)
# load model
model = load_model("Inception_model_on_field_data/Inception_model_100.hdf5")
# load model
predictions = model.predict(testX, batch_size=64)
report = classification_report(testY.argmax(axis=1), predictions.argmax(axis=1),
                               target_names=le.classes_, output_dict=True)
# saving the classification report in csv format
df = pd.DataFrame(report).transpose()
df.to_csv("classification_report_field.csv")
# Out:
# [INFO] processed 500/7719
# [INFO] processed 1000/7719
# [INFO] processed 1500/7719
# [INFO] processed 2000/7719
# [INFO] processed 2500/7719
# [INFO] processed 3000/7719
# [INFO] processed 3500/7719
# [INFO] processed 4000/7719
# [INFO] processed 4500/7719
# [INFO] processed 5000/7719
# [INFO] processed 5500/7719
# [INFO] processed 6000/7719
# [INFO] processed 6500/7719
# [INFO] processed 7000/7719
# [INFO] processed 7500/7719

# %%
pd.read_csv("classification_report_field.csv")
# Out:
#              Unnamed: 0  precision    recall  f1-score     support
# 0        abies_concolor   1.000000  1.000000  1.000000    10.00000
# 1    abies_nordmanniana   1.000000  0.714286  0.833333     7.00000
# 2        acer_campestre   1.000000  1.000000  1.000000     7.00000
# 3          acer_ginnala   1.000000  1.000000  1.000000     6.00000
# 4          acer_griseum   1.000000  0.888889  0.941176     9.00000
# ..                  ...        ...       ...       ...         ...
# 182         ulmus_rubra   1.000000  0.900000  0.947368    10.00000
# 183     zelkova_serrata   0.928571  1.000000  0.962963    13.00000
# 184            accuracy   0.933290  0.933290  0.933290     0.93329
# 185           macro avg   0.946041  0.933830  0.936192  1544.00000
# 186        weighted avg   0.932722  0.933290  0.930361  1544.00000
#
# [187 rows x 5 columns]
